# %% [markdown]
# ### Neural Networks
# - 궁극적인 인간의 꿈 : 컴퓨터가 인간을 대신해서 일을 해준다.
# - 즉, Thinking Machine 을 생각하며 뇌를 연구했다.
# - 생각보다 아주 복잡한 구조로 연결되어 있어서 놀랐다.
# - 연결구조를 좀더 깊이 있게 보았더니 단순하게 동작하는데 또한번 놀랐다.
# - 뉴런이 연결되어 있으면 활성화가 되었고, 연결되어 있지않으면 비활성화로 되어 있어,이정도면 구현가능하겠다는 생각으로 Neural Networks를 구현하기 시작하였다.
#
# → 이것이 초창기의 '인공지능' 이었다.

# %% [markdown]
# #### Biological Neuron
# The Navy revealed the embryo of an eletronic computer today that it expects will be able to walk, talk, see, write, reproduce itself an be conscious of its existence... Dr. Frank Rosenblatt
#
# [The New York Times, July 08, 1958]

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 뉴런들 간의 연결 구조

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Synapse

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Activation Functions

# %% [markdown]
# ![image.png](attachment:image.png)
