# %%
import tensorflow as tf

# %%
x_data = [1, 2, 3, 4, 5]
y_data = [10, 20, 30, 40, 50]

# %%
W = tf.Variable(tf.random_normal([1], -1.0, 1.0))
b = tf.Variable(tf.random_normal([1], -1.0, 1.0))

# %%
print(W)
# Out:
# <tf.Variable 'Variable:0' shape=(1,) dtype=float32_ref>

# %%
print(b)
# Out:
# <tf.Variable 'Variable_1:0' shape=(1,) dtype=float32_ref>

# %%
X = tf.placeholder(tf.float32, name = 'X')
Y = tf.placeholder(tf.float32, name = 'Y')
print(X)
print(Y)
# Out:
# Tensor("X_1:0", dtype=float32)
# Tensor("Y_1:0", dtype=float32)

# %%
score = W * X + b

# %%
loss = tf.reduce_mean(tf.square(score - Y))
loss
# Out:
# <tf.Tensor 'Mean_1:0' shape=() dtype=float32>

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate = 0.01)
train_op = optimizer.minimize(loss)
train_op
# Out:
# <tf.Operation 'GradientDescent_2' type=NoOp>

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(100):
        _, loss_val = sess.run([train_op, loss], feed_dict = {X: x_data, Y: y_data})
        print(step, 'Loss = %-10.5f' % loss_val, 'W = % 10.6f' % sess.run(W), 'B = %10.6f' % sess.run(b))
# Out:
# 0 Loss = 1683.71802 W =   0.717536 B =  -0.597500
# 1 Loss = 981.44012  W =   2.795528 B =  -0.028602
# 2 Loss = 572.18573  W =   4.382228 B =   0.404238
# 3 Loss = 333.69086  W =   5.593884 B =   0.733220
# 4 Loss = 194.70621  W =   6.519236 B =   0.982922
# 5 Loss = 113.71111  W =   7.226029 B =   1.172109
# 6 Loss = 66.50952   W =   7.765976 B =   1.315106
# 7 Loss = 39.00114   W =   8.178555 B =   1.422845
# 8 Loss = 22.96899   W =   8.493902 B =   1.503675
# 9 Loss = 13.62459   W =   8.735023 B =   1.563967
# 10 Loss = 8.17752    W =   8.919480 B =   1.608586
# 11 Loss = 5.00165    W =   9.060679 B =   1.641246
# 12 Loss = 3.14930    W =   9.168856 B =   1.664780
# 13 Loss = 2.06827    W =   9.251821 B =   1.681353
# 14 Loss = 1.43672    W =   9.315538 B =   1.692617
# 15 Loss = 1.06713    W =   9.364563 B =   1.699832
# 16 Loss = 0.85019    W =   9.402369 B =   1.703962
# 17 Loss = 0.72223    W =   9.431610 B =   1.705740
# 18 Loss = 0.64613    W =   9.454311 B =   1.705729
# 19 Loss = 0.60027    W =   9.472019 B =   1.704356
# 20 Loss = 0.57203    W =   9.485913 B =   1.701947
# 21 Loss = 0.55407    W =   9.496896 B =   1.698754
# 22 Loss = 0.54212    W =   9.505653 B =   1.694965
# 23 Loss = 0.53367    W =   9.512712 B =   1.690726
# 24 Loss = 0.52728    W =   9.518472 B =   1.686149
# 25 Loss = 0.52209    W =   9.523239 B =   1.681318
# 26 Loss = 0.51762    W =   9.527247 B =   1.676297
# 27 Loss = 0.51357    W =   9.530675 B =   1.671136
# 28 Loss = 0.50979    W =   9.533658 B =   1.665873
# 29 Loss = 0.50616    W =   9.536301 B =   1.660536
# 30 Loss = 0.50263    W =   9.538682 B =   1.655147
# 31 Loss = 0.49917    W =   9.540863 B =   1.649723
# 32 Loss = 0.49577    W =   9.542890 B =   1.644277
# 33 Loss = 0.49240    W =   9.544797 B =   1.638818
# 34 Loss = 0.48906    W =   9.546613 B =   1.633354
# 35 Loss = 0.48575    W =   9.548357 B =   1.627890
# 36 Loss = 0.48247    W =   9.550045 B =   1.622431
# 37 Loss = 0.47921    W =   9.551689 B =   1.616980
# 38 Loss = 0.47597    W =   9.553299 B =   1.611539
# 39 Loss = 0.47276    W =   9.554881 B =   1.606110
# 40 Loss = 0.46957    W =   9.556440 B =   1.600695
# 41 Loss = 0.46640    W =   9.557981 B =   1.595295
# 42 Loss = 0.46325    W =   9.559507 B =   1.589910
# 43 Loss = 0.46012    W =   9.561021 B =   1.584541
# 44 Loss = 0.45702    W =   9.562524 B =   1.579189
# 45 Loss = 0.45393    W =   9.564017 B =   1.573854
# 46 Loss = 0.45087    W =   9.565502 B =   1.568536
# 47 Loss = 0.44782    W =   9.566979 B =   1.563235
# 48 Loss = 0.44480    W =   9.568450 B =   1.557951
# 49 Loss = 0.44180    W =   9.569914 B =   1.552685
# 50 Loss = 0.43882    W =   9.571372 B =   1.547437
# 51 Loss = 0.43585    W =   9.572824 B =   1.542206
# 52 Loss = 0.43291    W =   9.574270 B =   1.536992
# 53 Loss = 0.42999    W =   9.575711 B =   1.531796
# 54 Loss = 0.42709    W =   9.577147 B =   1.526618
# 55 Loss = 0.42420    W =   9.578578 B =   1.521456
# 56 Loss = 0.42134    W =   9.580004 B =   1.516313
# 57 Loss = 0.41850    W =   9.581424 B =   1.511186
# 58 Loss = 0.41567    W =   9.582839 B =   1.506077
# 59 Loss = 0.41286    W =   9.584249 B =   1.500985
# 60 Loss = 0.41008    W =   9.585655 B =   1.495911
# 61 Loss = 0.40731    W =   9.587056 B =   1.490853
# 62 Loss = 0.40456    W =   9.588452 B =   1.485813
# 63 Loss = 0.40183    W =   9.589844 B =   1.480789
# 64 Loss = 0.39912    W =   9.591230 B =   1.475783
# 65 Loss = 0.39642    W =   9.592612 B =   1.470793
# 66 Loss = 0.39375    W =   9.593990 B =   1.465821
# 67 Loss = 0.39109    W =   9.595364 B =   1.460865
# 68 Loss = 0.38845    W =   9.596732 B =   1.455926
# 69 Loss = 0.38583    W =   9.598096 B =   1.451003
# 70 Loss = 0.38322    W =   9.599455 B =   1.446098
# 71 Loss = 0.38063    W =   9.600809 B =   1.441208
# 72 Loss = 0.37807    W =   9.602159 B =   1.436336
# 73 Loss = 0.37551    W =   9.603503 B =   1.431479
# 74 Loss = 0.37298    W =   9.604844 B =   1.426640
# 75 Loss = 0.37046    W =   9.606180 B =   1.421816
# 76 Loss = 0.36796    W =   9.607512 B =   1.417009
# 77 Loss = 0.36548    W =   9.608838 B =   1.412218
# 78 Loss = 0.36301    W =   9.610161 B =   1.407444
# 79 Loss = 0.36056    W =   9.611479 B =   1.402685
# 80 Loss = 0.35812    W =   9.612792 B =   1.397943
# 81 Loss = 0.35571    W =   9.614101 B =   1.393216
# 82 Loss = 0.35331    W =   9.615406 B =   1.388506
# 83 Loss = 0.35092    W =   9.616707 B =   1.383811
# 84 Loss = 0.34855    W =   9.618003 B =   1.379133
# 85 Loss = 0.34620    W =   9.619294 B =   1.374470
# 86 Loss = 0.34386    W =   9.620582 B =   1.369823
# 87 Loss = 0.34154    W =   9.621864 B =   1.365191
# 88 Loss = 0.33923    W =   9.623142 B =   1.360576
# 89 Loss = 0.33694    W =   9.624416 B =   1.355976
# 90 Loss = 0.33467    W =   9.625687 B =   1.351391
# 91 Loss = 0.33241    W =   9.626952 B =   1.346822
# 92 Loss = 0.33017    W =   9.628213 B =   1.342269
# 93 Loss = 0.32794    W =   9.629470 B =   1.337730
# 94 Loss = 0.32572    W =   9.630723 B =   1.333208
# 95 Loss = 0.32353    W =   9.631971 B =   1.328700
# 96 Loss = 0.32134    W =   9.633216 B =   1.324208
# 97 Loss = 0.31917    W =   9.634456 B =   1.319731
# 98 Loss = 0.31702    W =   9.635692 B =   1.315269
# 99 Loss = 0.31488    W =   9.636923 B =   1.310822

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(1001):
        _, loss_val = sess.run([train_op, loss], feed_dict = {X: x_data, Y: y_data})
        if step % 10 == 0:
            print(step, loss_val, sess.run(W), sess.run(b))
            
    print('Y = {Weight} * X + {Bias}'.format(Weight = sess.run(W), Bias = sess.run(b)))
    print('X:5, Y:', sess.run(score, feed_dict = {X: 5}))
    print('X:2.5, Y:', sess.run(score, feed_dict = {X: 2.5}))
# Out:
# 0 1360.7523 [1.8625245] [-1.2897604]
# 10 6.2828383 [9.23] [0.71880484]
# 20 0.15609129 [9.7325735] [0.8269715]
# 30 0.1200541 [9.773532] [0.80831176]
# 40 0.11207564 [9.783228] [0.7819918]
# 50 0.10473456 [9.79059] [0.7559915]
# 60 0.09787597 [9.797573] [0.73082006]
# 70 0.0914661 [9.804315] [0.70648414]
# 80 0.08547598 [9.810831] [0.68295836]
# 90 0.079878084 [9.817131] [0.6602161]
# 100 0.0746467 [9.82322] [0.638231]
# 110 0.069758214 [9.829106] [0.6169781]
# 120 0.06518944 [9.834798] [0.5964328]
# 130 0.06091974 [9.8403] [0.5765714]
# 140 0.05693073 [9.845617] [0.55737156]
# 150 0.053202342 [9.850759] [0.53881115]
# 160 0.049717575 [9.855727] [0.52086866]
# 170 0.046461567 [9.860532] [0.5035238]
# 180 0.04341879 [9.865176] [0.4867567]
# 190 0.040575057 [9.869666] [0.4705478]
# 200 0.037917875 [9.874006] [0.45487842]
# 210 0.0354347 [9.878202] [0.4397306]
# 220 0.03311393 [9.882257] [0.42508748]
# 230 0.030945312 [9.886178] [0.41093224]
# 240 0.028918553 [9.889968] [0.3972484]
# 250 0.027024705 [9.893632] [0.38402027]
# 260 0.025254708 [9.897175] [0.37123257]
# 270 0.02360106 [9.900599] [0.3588706]
# 280 0.022055117 [9.903909] [0.3469204]
# 290 0.02061106 [9.907108] [0.33536813]
# 300 0.019261017 [9.910201] [0.3242006]
# 310 0.017999874 [9.913192] [0.31340498]
# 320 0.016820904 [9.916082] [0.3029686]
# 330 0.015719336 [9.918878] [0.29287982]
# 340 0.014689748 [9.921579] [0.28312665]
# 350 0.0137276575 [9.9241905] [0.27369836]
# 360 0.012828728 [9.926715] [0.2645839]
# 370 0.0119883865 [9.929155] [0.25577307]
# 380 0.011203243 [9.931514] [0.24725582]
# 390 0.010469577 [9.933794] [0.2390223]
# 400 0.009784019 [9.936] [0.23106311]
# 410 0.009143321 [9.93813] [0.22336847]
# 420 0.0085444 [9.94019] [0.21593036]
# 430 0.007984743 [9.942183] [0.20874004]
# 440 0.0074619586 [9.944108] [0.20178884]
# 450 0.006973135 [9.945969] [0.19506925]
# 460 0.006516541 [9.947768] [0.18857346]
# 470 0.0060898084 [9.949508] [0.18229397]
# 480 0.0056908713 [9.951189] [0.17622355]
# 490 0.0053182943 [9.952814] [0.17035547]
# 500 0.0049699005 [9.954385] [0.16468282]
# 510 0.00464446 [9.955904] [0.15919907]
# 520 0.0043403255 [9.957373] [0.15389809]
# 530 0.004056109 [9.958793] [0.14877316]
# 540 0.003790421 [9.960165] [0.14381887]
# 550 0.00354223 [9.961492] [0.13902956]
# 560 0.0033101353 [9.962773] [0.13439967]
# 570 0.0030934499 [9.964013] [0.12992404]
# 580 0.0028907938 [9.965212] [0.12559743]
# 590 0.0027014925 [9.966371] [0.12141484]
# 600 0.0025244749 [9.96749] [0.1173716]
# 610 0.0023591104 [9.968573] [0.11346323]
# 620 0.0022046738 [9.969619] [0.10968494]
# 630 0.002060296 [9.970631] [0.10603245]
# 640 0.0019254157 [9.971608] [0.10250171]
# 650 0.0017992243 [9.972554] [0.09908857]
# 660 0.0016814426 [9.973468] [0.0957889]
# 670 0.0015712824 [9.974351] [0.0925994]
# 680 0.0014684268 [9.975205] [0.08951601]
# 690 0.0013721954 [9.976031] [0.08653507]
# 700 0.0012823206 [9.97683] [0.08365331]
# 710 0.001198438 [9.977601] [0.08086764]
# 720 0.0011199092 [9.978347] [0.07817481]
# 730 0.0010465864 [9.979068] [0.0755716]
# 740 0.0009780674 [9.979764] [0.0730553]
# 750 0.0009139866 [9.980439] [0.07062273]
# 760 0.0008541162 [9.981091] [0.06827086]
# 770 0.00079815247 [9.98172] [0.06599737]
# 780 0.00074593595 [9.982328] [0.06379957]
# 790 0.00069705566 [9.982917] [0.06167514]
# 800 0.00065145816 [9.983486] [0.05962132]
# 810 0.00060874707 [9.9840355] [0.05763588]
# 820 0.0005689234 [9.984567] [0.05571685]
# 830 0.000531653 [9.985081] [0.05386167]
# 840 0.0004968199 [9.985578] [0.0520681]
# 850 0.00046426273 [9.986058] [0.05033446]
# 860 0.00043387423 [9.986522] [0.04865855]
# 870 0.00040544267 [9.986971] [0.04703818]
# 880 0.00037890402 [9.987405] [0.04547193]
# 890 0.00035413672 [9.9878235] [0.04395801]
# 900 0.00033089865 [9.988229] [0.04249467]
# 910 0.00030927573 [9.988622] [0.04108001]
# 920 0.00028897275 [9.989] [0.03971203]
# 930 0.0002700768 [9.989367] [0.03838965]
# 940 0.00025238015 [9.98972] [0.03711135]
# 950 0.00023585442 [9.990063] [0.035876]
# 960 0.00022043548 [9.990394] [0.03468145]
# 970 0.00020597538 [9.990713] [0.03352653]
# 980 0.00019250817 [9.991022] [0.03241035]
# 990 0.00017990096 [9.991322] [0.03133125]
# 1000 0.00016810535 [9.991611] [0.03028796]
# Y = [9.991611] * X + [0.03028796]
# X:5, Y: [49.988342]
# X:2.5, Y: [25.009315]
