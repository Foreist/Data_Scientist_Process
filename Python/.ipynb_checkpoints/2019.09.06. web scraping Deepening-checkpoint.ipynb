# %%
과제1 : 맥도날드 홈페이지에서 서울지역의 모든 매장정보를 크롤링
과제2 : 크롤링한 데이터에서 서울시의 각 구별로 맥도날드매장 갯수를 집계하고 지도에 컬러맵으로 시각화
과제3 : 서울시 구별 인구대비 구별 맥도날드매장 수의 지표값(rate)을 만들고 컬럼 추가 저장
과제4 : 유동인구가 가장 많은 구 TOP5 유추
과제5 : 컬럼별 상관관계에 대한 정보를 시각화
# Out:
#   File "<ipython-input-1-228325969b04>", line 1
#     과제1 : 맥도날드 홈페이지에서 서울지역의 모든 매장정보를 크롤링
#                     ^
# SyntaxError: invalid syntax

# %%
import requests
from bs4 import BeautifulSoup

# %%
# 주소를 url에 넣는다.
url = "http://www.mcdonalds.co.kr/www/kor/findus/district.do?pageIndex=1&sSearch_yn=Y&skey=2&skey1=&skey2=&skeyword=%EC%84%9C%EC%9A%B8&skey4=&skey5=&skeyword2=&sflag1=&sflag2=&sflag3=&sflag4=&sflag5=&sflag6=&sflag=N"
html_mac = requests.get(url).text
mac = BeautifulSoup(html_mac, 'lxml')
mac.title # 제대로 실행했는지 사이트 확인
# Out:
# <title>지역별 - McDonald's</title>

# %%
# 매장정보를 담고 있는 변수
info = mac.find_all('dl', 'clearFix'); info
# Out:
# [<dl class="clearFix">
#  <dt><a href="javascript:moveMap('37.494879','127.130762');"> <img alt="A" src="../../common/images/kor/findus/1.gif"/> 가락DT점</a></dt>
#  <dd>070-7017-0622
#                                                          , 070-7017-0613
#
#                                                      </dd>
#  <dd>서울특별시 송파구 가락동 193-7</dd>
#  <!-- 도로명 검색주소 노출 -->
#  <dd class="road">[도로명주소]서울특별시 송파구 동남로 196 (가락동)</dd>
#  <dd class="infoCheck">
#  <table border="0" cellpadding="5" cellspacing="5">
#  <colgroup>
#  <col style="width:70px"/>
#  <col style="width:65.8px"/>
#  <!-- <col style="width:65.8px" /> -->
#  <col style="width:75.1px"/>
#  <col style="width:102px"/>
#  <col style="width:87px"/>
#  <col style="width:72px"/>
#  </colgroup>
#  <tbody>
#  <tr>
#  <td>
#
#
#
#
#  																			07:00~01:00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  																	</td>
# ...

# %%
# 항상 soup 상태에서는 find같은 거를 사용할 수 있음
# type(info)
info[0]
# Out:
# <dl class="clearFix">
# <dt><a href="javascript:moveMap('37.494879','127.130762');"> <img alt="A" src="../../common/images/kor/findus/1.gif"/> 가락DT점</a></dt>
# <dd>070-7017-0622
#                                                         , 070-7017-0613
#
#                                                     </dd>
# <dd>서울특별시 송파구 가락동 193-7</dd>
# <!-- 도로명 검색주소 노출 -->
# <dd class="road">[도로명주소]서울특별시 송파구 동남로 196 (가락동)</dd>
# <dd class="infoCheck">
# <table border="0" cellpadding="5" cellspacing="5">
# <colgroup>
# <col style="width:70px"/>
# <col style="width:65.8px"/>
# <!-- <col style="width:65.8px" /> -->
# <col style="width:75.1px"/>
# <col style="width:102px"/>
# <col style="width:87px"/>
# <col style="width:72px"/>
# </colgroup>
# <tbody>
# <tr>
# <td>
#
#
#
#
# 																			07:00~01:00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																	</td>
# <td><img alt="맥모닝 있음" src="../../common/images/kor/common/ico/ico_check.gif"/></td>
# ...

# %%
#이름, 전화번호, 주소
name_call_ad = [i.text for i in info];name_call_ad

# \t 없애주기
for text in name_call_ad:
# Out:
# str

# %%
# text_c = c.text;text_c
q = text_c.replace('\t', '')
qq = q.replace('\n', '')
qqq = qq.replace('\r', ''); qqq
# spl1 = text_c.split('\n')
# Out:
# '  가락DT점070-7017-0622                                                        , 070-7017-0613                                                                                                            서울특별시 송파구 가락동 193-7[도로명주소]서울특별시 송파구 동남로 196 (가락동)07:00~01:0007:00~01:00 '

# %%
text_c = c.text
text_c.find('\n\n\n')
# 원하는 정보만 찾았으니 \rㅇ
tt = text_c[:text_c.find('\n\n\n')]; tt
# Out:
# '\n  가락DT점\n070-7017-0622\r\n                                                        , 070-7017-0613\r\n                                                        \r\n                                                    \n서울특별시 송파구 가락동 193-7\n\n[도로명주소]서울특별시 송파구 동남로 196 (가락동)'

# %%
# 이름
tt[tt.find(' ')+2: tt.find('\n0')]
# Out:
# '가락DT점'

# %%
# 주소
tt[tt.find('서울'):tt.rfind('\n')-1]
# Out:
# '서울특별시 송파구 가락동 193-7'

# %%
# 도로명 주소
tt[tt.find('[도로명주소]')+7:]
# Out:
# '서울특별시 송파구 동남로 196 (가락동)'

# %%
type(text_c)
# Out:
# str

# %%
# 영업시간,맥모닝, 맥올데이, 시그니처버거, 맥딜리버리 시간, 맥드라이브
#c가 [리스트[수프]]
# for i in c[3]:
#     type(i)

c[3].find('tbody')
# Out:
# <tbody>
# <tr>
# <td>
#
# 																			24시간
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																	</td>
# <td><img alt="맥모닝 있음" src="../../common/images/kor/common/ico/ico_check.gif"/></td>
# <td><img alt="맥올데이 있음" src="../../common/images/kor/common/ico/ico_check.gif"/></td>
# <td><img alt="Signature Burger 있음" src="../../common/images/kor/common/ico/ico_check.gif"/></td>
# <!-- <td></td> -->
# <td>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																				08:00~24:00
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 																	</td>
# <td></td>
# </tr>
# </tbody>
