# %% [markdown]
# ## EDA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
train = pd.read_csv('./data/train.csv')
test = pd.read_csv('./data/test.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize = (18, 8))
train['Survived'].value_counts().plot.pie(explode = [0, 0.1], autopct = '%.1f%%', ax = ax[0], shadow = True)
ax[0].set_title('Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data = train, ax= ax[1])
ax[1].set_title('Survived')
plt.show()

# %%
train.groupby(['Sex', 'Survived'])['Survived'].count()
# Out:
# Sex     Survived
# female  0            81
#         1           233
# male    0           468
#         1           109
# Name: Survived, dtype: int64

# %%
f, ax = plt.subplots(1, 2, figsize = (18, 8))
train[['Sex', 'Survived']].groupby(['Sex']).mean().plot.bar(ax = ax[0])
ax[0].set_title('Survived vs Sex')
sns.countplot('Sex', hue = 'Survived', data = train, ax = ax[1])
ax[1].set_title('Sex: Survived vs Dead')
plt.show()

# %% [markdown]
# ## Pclass -> Ordinal Feature

# %%
pd.crosstab(train['Pclass'], train['Survived'], margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
#     #T_4c7c0a98_df66_11e9_841a_003067a47e0crow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_4c7c0a98_df66_11e9_841a_003067a47e0crow3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_4c7c0a98_df66_11e9_841a_003067a47e0c" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4c7c0a98_df66_11e9_841a_003067a47e0clevel0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow0_col0" class="data row0 col0" >80</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow0_col1" class="data row0 col1" >136</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_4c7c0a98_df66_11e9_841a_003067a47e0clevel0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow1_col0" class="data row1 col0" >97</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow1_col1" class="data row1 col1" >87</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_4c7c0a98_df66_11e9_841a_003067a47e0clevel0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow2_col0" class="data row2 col0" >372</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow2_col1" class="data row2 col1" >119</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_4c7c0a98_df66_11e9_841a_003067a47e0clevel0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow3_col0" class="data row3 col0" >549</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow3_col1" class="data row3 col1" >342</td>
#                         <td id="T_4c7c0a98_df66_11e9_841a_003067a47e0crow3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
f, ax = plt.subplots(1, 2, figsize = (18, 8))
train['Pclass'].value_counts().plot.bar(color = ['#CD7F32', '#FFDF00', '#D3D3D3'], ax = ax[0])
ax[0].set_title('Number Of Passengers By Pclass')
ax[0].set_ylabel('Count')
sns.countplot('Pclass', hue = 'Survived', data = train, ax = ax[1])
ax[1].set_title('Pclass: Survived vs Dead')
plt.show()

# %%
pd.crosstab([train.Sex, train.Survived], train.Pclass, margins = True).style.background_gradient(cmap = 'summer_r')
# Out:
# <style  type="text/css" >
#     #T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col3 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col0 {
#             background-color:  #96cb66;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col1 {
#             background-color:  #a3d166;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col2 {
#             background-color:  #f1f866;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col3 {
#             background-color:  #cfe766;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col0 {
#             background-color:  #a7d366;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col1 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col2 {
#             background-color:  #6eb666;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col3 {
#             background-color:  #85c266;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col0 {
#             background-color:  #cde666;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col1 {
#             background-color:  #f0f866;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col3 {
#             background-color:  #f7fb66;
#             color:  #000000;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col3 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_d4efdffa_df66_11e9_81db_003067a47e0c" ><thead>    <tr>        <th class="blank" ></th>        <th class="index_name level0" >Pclass</th>        <th class="col_heading level0 col0" >1</th>        <th class="col_heading level0 col1" >2</th>        <th class="col_heading level0 col2" >3</th>        <th class="col_heading level0 col3" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="index_name level1" >Survived</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel0_row0" class="row_heading level0 row0" rowspan=2>female</th>
#                         <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel1_row0" class="row_heading level1 row0" >0</th>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col0" class="data row0 col0" >3</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col1" class="data row0 col1" >6</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col2" class="data row0 col2" >72</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow0_col3" class="data row0 col3" >81</td>
#             </tr>
#             <tr>
#                                 <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel1_row1" class="row_heading level1 row1" >1</th>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col0" class="data row1 col0" >91</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col1" class="data row1 col1" >70</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col2" class="data row1 col2" >72</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow1_col3" class="data row1 col3" >233</td>
#             </tr>
#             <tr>
#                         <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel0_row2" class="row_heading level0 row2" rowspan=2>male</th>
#                         <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel1_row2" class="row_heading level1 row2" >0</th>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col0" class="data row2 col0" >77</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col1" class="data row2 col1" >91</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col2" class="data row2 col2" >300</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow2_col3" class="data row2 col3" >468</td>
#             </tr>
#             <tr>
#                                 <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel1_row3" class="row_heading level1 row3" >1</th>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col0" class="data row3 col0" >45</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col1" class="data row3 col1" >17</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col2" class="data row3 col2" >47</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow3_col3" class="data row3 col3" >109</td>
#             </tr>
#             <tr>
#                         <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel0_row4" class="row_heading level0 row4" >All</th>
#                         <th id="T_d4efdffa_df66_11e9_81db_003067a47e0clevel1_row4" class="row_heading level1 row4" ></th>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col0" class="data row4 col0" >216</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col1" class="data row4 col1" >184</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col2" class="data row4 col2" >491</td>
#                         <td id="T_d4efdffa_df66_11e9_81db_003067a47e0crow4_col3" class="data row4 col3" >891</td>
#             </tr>
#     </tbody></table>

# %%
sns.factorplot('Pclass', 'Survived', hue = 'Sex', data = train)
plt.show()

# %%
## Age -> Continuous Feature
print('Oldest Passenger was of: {} Years'.format(train['Age'].max()))
print('Youngest Passenger was of: {} Years'.format(train['Age'].min()))
print('Average Age on the ship: {:.2f} Years'.format(train['Age'].mean()))
# Out:
# Oldest Passenger was of: 80.0 Years
# Youngest Passenger was of: 0.42 Years
# Average Age on the ship: 29.70 Years

# %%
f, ax = plt.subplots(1, 2, figsize = (13, 8))
sns.violinplot('Pclass', 'Age', hue = 'Survived', data = train, split = True, ax = ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0, 110, 10))
sns.violinplot('Sex', 'Age', hue = 'Survived', data = train, split = True, ax = ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0, 110, 10))
plt.show()

# %%
for i in data:
