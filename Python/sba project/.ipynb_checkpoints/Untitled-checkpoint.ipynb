# %%
import requests
from bs4 import BeautifulSoup
import requests

ServiceKey = "ePfZVL1%2BsyifhHhQoxgfW2sCTOIL71thr0v%2FSMFgGX7BPRmC4th9rUeE1kKSN7cteFjgQOvs%2F3f3G6DHB%2FQNvw%3D%3D"
url = "http://openapi.animal.go.kr/openapi/service/rest/abandonmentPublicSrvc/abandonmentPublic?bgnde=20140301&endde=20140430&pageNo=1&numOfRows=10&ServiceKey="
request = requests.get(url+ServiceKey).text
soup = BeautifulSoup(request, 'lxml')

# %%
print(soup.prettify())
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?>
# <html>
#  <body>
#   <response>
#    <header>
#     <resultcode>
#      00
#     </resultcode>
#     <resultmsg>
#      NORMAL SERVICE.
#     </resultmsg>
#    </header>
#    <items>
#     <item>
#      <age>
#       2-3년(년생)
#      </age>
#      <careaddr>
#       광주광역시 북구 본촌마을길 25 (본촌동, 건국동사무소) 광주 동물보호소
#      </careaddr>
#      <carenm>
#       광주 동물보호소
#      </carenm>
#      <caretel>
#       062-571-2808
#      </caretel>
#      <chargenm>
#       북구
#      </chargenm>
#      <colorcd>
#       황/흰색
#      </colorcd>
#      <desertionno>
#       429362201400243
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/06/201406231106389_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       북구 중흥동
#      </happenplace>
#      <kindcd>
#       [개] 믹스견
#      </kindcd>
#      <neuteryn>
#       N
#      </neuteryn>
#      <noticeedt>
#       20140703
#      </noticeedt>
#      <noticeno>
#       광주-북구-2014-00241
#      </noticeno>
#      <noticesdt>
#       20140623
#      </noticesdt>
#      <officetel>
#       062-410-6557
#      </officetel>
#      <orgnm>
#       광주광역시 북구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/06/201406231106389.jpg
#      </popfile>
#      <processstate>
#       종료(안락사)
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       최근미용, 마이크로칩
#      </specialmark>
#      <weight>
#       7.40(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       5년추정(년생)
#      </age>
#      <careaddr>
#       울산광역시 남구 대학로 112 (무거동)
#      </careaddr>
#      <carenm>
#       스마일동물병원
#      </carenm>
#      <caretel>
#       052-277-0075
#      </caretel>
#      <chargenm>
#       방효빈
#      </chargenm>
#      <colorcd>
#       흰색
#      </colorcd>
#      <desertionno>
#       431370201400365
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/04/201405021605820_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       무거동울산과학대앞
#      </happenplace>
#      <kindcd>
#       [개] 진도견
#      </kindcd>
#      <neuteryn>
#       N
#      </neuteryn>
#      <noticeedt>
#       20140620
#      </noticeedt>
#      <noticeno>
#       울산-남구-2014-00633
#      </noticeno>
#      <noticesdt>
#       20140610
#      </noticesdt>
#      <officetel>
#       052-226-5663
#      </officetel>
#      <orgnm>
#       울산광역시 남구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/04/201405021605820.jpg
#      </popfile>
#      <processstate>
#       종료(입양)
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       빨간목줄착용
#      </specialmark>
#      <weight>
#       25(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       한달미만(년생)
#      </age>
#      <careaddr>
#       경상북도 안동시 서후면 태장리 201-1
#      </careaddr>
#      <carenm>
#       안동시동물보호센터
#      </carenm>
#      <caretel>
#       010-7703-1999
#      </caretel>
#      <chargenm>
#       권오기
#      </chargenm>
#      <colorcd>
#       황색줄무늬
#      </colorcd>
#      <desertionno>
#       447507201400120
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/05/201405091605804_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       용상5주공
#      </happenplace>
#      <kindcd>
#       [고양이] 고양이
#      </kindcd>
#      <neuteryn>
#       N
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       경북-안동-2014-00116
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       054-840-5484
#      </officetel>
#      <orgnm>
#       경상북도 안동시
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/05/201405091605804.jpg
#      </popfile>
#      <processstate>
#       보호중
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       단모종,어린묘2마리
#      </specialmark>
#      <weight>
#       0.5(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       50일 추정(년생)
#      </age>
#      <careaddr>
#       대전광역시 유성구 갑동로15번길 20-39 (갑동)
#      </careaddr>
#      <carenm>
#       대전동물보호센터
#      </carenm>
#      <caretel>
#       042-825-1118
#      </caretel>
#      <chargenm>
#       대덕구
#      </chargenm>
#      <colorcd>
#       백
#      </colorcd>
#      <desertionno>
#       430368201400097
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/05/201405091705254_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       대전로 1215 대전병원(대화동) 후문 주변
#      </happenplace>
#      <kindcd>
#       [개] 진도견
#      </kindcd>
#      <neuteryn>
#       N
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       대전-대덕-2014-00094
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       042-608-6951
#      </officetel>
#      <orgnm>
#       대전광역시 대덕구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/05/201405091705254.jpg
#      </popfile>
#      <processstate>
#       종료(자연사)
#      </processstate>
#      <sexcd>
#       F
#      </sexcd>
#      <specialmark>
#       교통사고
#      </specialmark>
#      <weight>
#       3(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       4살추정(년생)
#      </age>
#      <careaddr>
#       대전광역시 유성구 갑동로15번길 20-39 (갑동)
#      </careaddr>
#      <carenm>
#       대전동물보호센터
#      </carenm>
#      <caretel>
#       042-825-1118
#      </caretel>
#      <chargenm>
#       대덕구
#      </chargenm>
#      <colorcd>
#       백
#      </colorcd>
#      <desertionno>
#       430368201400096
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/05/20140509170506_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       대청로82번길 147 보훈병원 근처(신탄진동)
#      </happenplace>
#      <kindcd>
#       [개] 믹스견
#      </kindcd>
#      <neuteryn>
#       U
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       대전-대덕-2014-00093
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       042-608-6951
#      </officetel>
#      <orgnm>
#       대전광역시 대덕구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/05/20140509170506.jpg
#      </popfile>
#      <processstate>
#       종료(입양)
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       옷착용
#      </specialmark>
#      <weight>
#       5(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       약 5-6년(년생)
#      </age>
#      <careaddr>
#       인천광역시 부평구 부평동 431-15
#      </careaddr>
#      <carenm>
#       백마동물병원
#      </carenm>
#      <caretel>
#       032-528-1359
#      </caretel>
#      <chargenm>
#       장상규
#      </chargenm>
#      <colorcd>
#       흰색, 갈색
#      </colorcd>
#      <desertionno>
#       428354201400158
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605482_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       부평구청당직실
#      </happenplace>
#      <kindcd>
#       [개] 포메라니안
#      </kindcd>
#      <neuteryn>
#       U
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       인천-부평-2014-00180
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       032-509-6553
#      </officetel>
#      <orgnm>
#       인천광역시 부평구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605482.jpg
#      </popfile>
#      <processstate>
#       종료(반환)
#      </processstate>
#      <sexcd>
#       F
#      </sexcd>
#      <specialmark>
#       털이 풍성한편, RFID 410100004009195
#      </specialmark>
#      <weight>
#       3(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       약 3-4년(년생)
#      </age>
#      <careaddr>
#       인천광역시 부평구 부평동 431-15
#      </careaddr>
#      <carenm>
#       백마동물병원
#      </carenm>
#      <caretel>
#       032-528-1359
#      </caretel>
#      <chargenm>
#       장상규
#      </chargenm>
#      <colorcd>
#       갈색
#      </colorcd>
#      <desertionno>
#       428354201400157
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605559_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       부개동 271-33
#      </happenplace>
#      <kindcd>
#       [개] 푸들
#      </kindcd>
#      <neuteryn>
#       U
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       인천-부평-2014-00179
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       032-509-6553
#      </officetel>
#      <orgnm>
#       인천광역시 부평구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605559.jpg
#      </popfile>
#      <processstate>
#       종료(안락사)
#      </processstate>
#      <sexcd>
#       F
#      </sexcd>
#      <specialmark>
#       친화적, 잘 짖는 편
#      </specialmark>
#      <weight>
#       4(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       약 10년(년생)
#      </age>
#      <careaddr>
#       인천광역시 부평구 부평동 431-15
#      </careaddr>
#      <carenm>
#       백마동물병원
#      </carenm>
#      <caretel>
#       032-528-1359
#      </caretel>
#      <chargenm>
#       장상규
#      </chargenm>
#      <colorcd>
#       흰색
#      </colorcd>
#      <desertionno>
#       428354201400156
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605283_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       동수동물병원
#      </happenplace>
#      <kindcd>
#       [개] 말티즈
#      </kindcd>
#      <neuteryn>
#       U
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       인천-부평-2014-00178
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       032-509-6553
#      </officetel>
#      <orgnm>
#       인천광역시 부평구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605283.jpg
#      </popfile>
#      <processstate>
#       종료(반환)
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       백내장, 중성화수술
#      </specialmark>
#      <weight>
#       4(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       약 4-5년(년생)
#      </age>
#      <careaddr>
#       인천광역시 부평구 부평동 431-15
#      </careaddr>
#      <carenm>
#       백마동물병원
#      </carenm>
#      <caretel>
#       032-528-1359
#      </caretel>
#      <chargenm>
#       장상규
#      </chargenm>
#      <colorcd>
#       흰색
#      </colorcd>
#      <desertionno>
#       428354201400155
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605752_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       산곡동 한화아파트
#      </happenplace>
#      <kindcd>
#       [개] 말티즈
#      </kindcd>
#      <neuteryn>
#       U
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       인천-부평-2014-00177
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       032-509-6553
#      </officetel>
#      <orgnm>
#       인천광역시 부평구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605752.jpg
#      </popfile>
#      <processstate>
#       종료(안락사)
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       친화적, 중성화수술, 파란색 목줄
#      </specialmark>
#      <weight>
#       3.5(Kg)
#      </weight>
#     </item>
#     <item>
#      <age>
#       약 2-3개월(년생)
#      </age>
#      <careaddr>
#       인천광역시 부평구 부평동 431-15
#      </careaddr>
#      <carenm>
#       백마동물병원
#      </carenm>
#      <caretel>
#       032-528-1359
#      </caretel>
#      <chargenm>
#       장상규
#      </chargenm>
#      <colorcd>
#       갈색, 흰색
#      </colorcd>
#      <desertionno>
#       428354201400154
#      </desertionno>
#      <filename>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605606_s.jpg
#      </filename>
#      <happendt>
#       20140430
#      </happendt>
#      <happenplace>
#       청천동 175-42
#      </happenplace>
#      <kindcd>
#       [개] 믹스견
#      </kindcd>
#      <neuteryn>
#       U
#      </neuteryn>
#      <noticeedt>
#       20140519
#      </noticeedt>
#      <noticeno>
#       인천-부평-2014-00176
#      </noticeno>
#      <noticesdt>
#       20140509
#      </noticesdt>
#      <officetel>
#       032-509-6553
#      </officetel>
#      <orgnm>
#       인천광역시 부평구
#      </orgnm>
#      <popfile>
#       http://www.animal.go.kr/files/shelter/2014/04/201405031605606.jpg
#      </popfile>
#      <processstate>
#       종료(안락사)
#      </processstate>
#      <sexcd>
#       M
#      </sexcd>
#      <specialmark>
#       허약자견
#      </specialmark>
#      <weight>
#       2(Kg)
#      </weight>
#     </item>
#    </items>
#    <numofrows>
#     10
#    </numofrows>
#    <pageno>
#     1
#    </pageno>
#    <totalcount>
#     12158
#    </totalcount>
#   </response>
#  </body>
# </html>

# %%
import requests
url = 'http://kosis.kr/kosisapi/service/IndicatorService/IndListSearchRequest?STAT_JIPYO_NM=%EA%B0%95%EC%88%98%EB%9F%89&ServiceKey='
key = '1ptXKsV3OjZ4XpbdTu2yAjjHgCjiFSF2h2X5dOa%2F1YuXAqOmRYRdZVUC%2Fr1YB%2BC%2BsS%2BTdydJYgs%2B0uqfN7gxRg%3D%3D'
print(requests.get(url+key).text)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><responseTime>2019-09-10T17:03:38.542+09:00</responseTime><resultCode>30</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>
