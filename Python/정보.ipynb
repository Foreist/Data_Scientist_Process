# %%
데이터 다운 받을 때

# !wget https://github.com/rickiepark/deep-learning-with-python-notebooks/archive/master.zip
# !unzip master.zip
# !mv deep-learning-with-python-notebooks-master/datasets ./
# Out:
#   File "<ipython-input-3-e5f719127a5d>", line 1
#     데이터 다운 받을 때
#          ^
# SyntaxError: invalid syntax

# %%
주소 변경
https://github.com/rickiepark/~~~~
https://colab.research.google.com/github/rickiepark/~~~~

# %%
# !cd /content/gdrive; ls-al;
# Out:
# /bin/bash: ls-al: command not found

# %%
#구글드라이브 코랩 연동

from google.colab import auth
auth.authenticate_user()

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# colab에서 drive란 폴더를 만든 후, 우리 구글 드라이브의 root와 drive 폴더를 연결(mount)

# !cd gdrive/data; ls-al;

# %%
#파일 업로드 하기

from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6ba4259f-8db4-44c9-9eb8-036db2275a8c" name="files[]" multiple disabled />
#      <output id="result-6ba4259f-8db4-44c9-9eb8-036db2275a8c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 종 분류해야 함.xlsx to 종 분류해야 함.xlsx

# %%
#현재 연결된 곳에 뭐 있는지
ls-al;
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 ./
# drwxr-xr-x 1 root root 4096 Aug  1 03:36 ../
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 .config/
# drwxr-xr-x 1 root root 4096 Jul 19 16:14 sample_data/

# %%
# !ls "gdrive/My Drive"
# Out:
#  수련회
#  속기행사정보
# '1.4 데이터 핸들링 - 판다스.ipynb의 사본 - Colaboratory (1).pdf'
# '1.4 데이터 핸들링 - 판다스.ipynb의 사본 - Colaboratory (2).pdf'
# '1.4 데이터 핸들링 - 판다스.ipynb의 사본 - Colaboratory.pdf'
#  AUD
# 'Colab Notebooks'
#  Notability
#  titanic_train1.csv

# %%
# !ls '/content/gdrive/My Drive/Colab Notebooks/
# Out:
# cp: missing destination file operand after 'gdrive/My Drive/Colab Notebooks/파이썬 머신러닝 완벽 가이드/pandas.ipynb/'
# Try 'cp --help' for more information.

# %%
# !jupyter nbconvert --to <PDF> <pandas.ipynb>
# Out:
# /bin/bash: -c: line 0: syntax error near unexpected token `<'
# /bin/bash: -c: line 0: `jupyter nbconvert --to <PDF> <pandas.ipynb>'
